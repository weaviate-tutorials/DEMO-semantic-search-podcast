# %% [markdown]
# # Using Weaviate embedded for question/answering on your vector store

# %% [markdown]
# In this tutorial we use Weaviate Embedded to create a vector store and question/answering from transcribed podcasts. The steps will include uploading your data from a local store, and creating a schema as well as an object store.

# %%
import weaviate
from weaviate.embedded import EmbeddedOptions
from weaviate.util import generate_uuid5
import json
import helper

# %% [markdown]
# An embedded Weaviate instance allows us to have the source data saved and retrieved locally, while having access to the vectorizing modules available.

# %%
client = weaviate.Client(
    embedded_options=EmbeddedOptions(
        additional_env_vars={
        "ENABLE_MODULES":
        "text2vec-openai,text2vec-cohere,text2vec-huggingface"}
    )
)
# Out:
# Started /Users/tdubon/.cache/weaviate-embedded: process ID 3033
# {"action":"startup","default_vectorizer_module":"none","level":"info","msg":"the default vectorizer modules is set to \"none\", as a result all new schema classes without an explicit vectorizer setting, will use this vectorizer","time":"2023-10-04T11:54:33-07:00"}
# {"action":"startup","auto_schema_enabled":true,"level":"info","msg":"auto schema enabled setting is set to \"true\"","time":"2023-10-04T11:54:33-07:00"}
# {"action":"hnsw_vector_cache_prefill","count":3000,"index_id":"podcast_ORJj3GQyYa6n","level":"info","limit":1000000000000,"msg":"prefilled vector cache","time":"2023-10-04T11:54:33-07:00","took":124744}
# {"level":"warning","msg":"Multiple vector spaces are present, GraphQL Explore and REST API list objects endpoint module include params has been disabled as a result.","time":"2023-10-04T11:54:33-07:00"}
# {"action":"grpc_startup","level":"info","msg":"grpc server listening at [::]:50051","time":"2023-10-04T11:54:33-07:00"}
# {"action":"restapi_management","level":"info","msg":"Serving weaviate at http://127.0.0.1:6666","time":"2023-10-04T11:54:33-07:00"}

# %%
#Print the client information to confirm the modules are loaded.
meta_info = client.get_meta()
print(json.dumps(meta_info, indent=2))
# Out:
# {
#   "hostname": "http://127.0.0.1:6666",
#   "modules": {
#     "text2vec-cohere": {
#       "documentationHref": "https://docs.cohere.ai/embedding-wiki/",
#       "name": "Cohere Module"
#     },
#     "text2vec-huggingface": {
#       "documentationHref": "https://huggingface.co/docs/api-inference/detailed_parameters#feature-extraction-task",
#       "name": "Hugging Face Module"
#     },
#     "text2vec-openai": {
#       "documentationHref": "https://platform.openai.com/docs/guides/embeddings/what-are-embeddings",
#       "name": "OpenAI Module"
#     }
#   },
#   "version": "1.21.1"
# }

# %% [markdown]
# In the cell below we setup the schema, an outline requiring the data type, vectorizer and the list of classes. Note that it is essential to have your data cleaned and the categories clearly identified for this step. If using your own vectorizer, "none" should be specified for "vectorizer".

# %%
client.schema.delete_all()
schema = {
    "classes": [
        {
            "class": "Podcast",
            "vectorizer": "text2vec-cohere",
            "properties": [
                {
                    "name": "title",
                    "dataType": ["text"]
                },
                {
                    "name": "transcript",
                    "dataType": ["text"]
                }
            ]
        }
    ]
}
client.schema.create(schema)
# Out:
# {"action":"hnsw_vector_cache_prefill","count":1000,"index_id":"podcast_pEughRQxrV7H","level":"info","limit":1000000000000,"msg":"prefilled vector cache","time":"2023-10-04T11:54:48-07:00","took":92722}

# %% [markdown]
# In the following cells we load the locally stored data (in json format) and create a function definition for an add_podcast object.
#
# The name of the object represents the highest level classification for your data, indicated below as podcast_object (in dictionary type). Target class represents the next level in the classification of your data. Here we indicate it below as the string "Podcast", but note that multiple classes could have been specified, for example, if we had different categories of podcasts, such as English, Spanish, etc.
#
# The function definition below is implementing batch_size=1. Note that with larger amounts of data you will want to adjust this setting. Per the documentation: "batch imports are used to maximize import speed and minimize network latency. Batch import processes multiple objects per request, and clients can parallelize the process."

# %%
with open("/Users/tdubon/DEMO-semantic-search-podcast/data/podcast_ds.json", 'r') as f:
    datastore = json.load(f)
# Out:
# {"action":"read_disk_use","level":"warning","msg":"disk usage currently at 97.30%, threshold set to 80.00%","path":"/Users/tdubon/.local/share/weaviate","time":"2023-10-04T11:55:03-07:00"}
# {"action":"lsm_compaction","class":"Podcast","index":"podcast","level":"warning","msg":"compaction halted due to shard READONLY status","path":"/Users/tdubon/.local/share/weaviate/podcast_pEughRQxrV7H_lsm","shard":"pEughRQxrV7H","time":"2023-10-04T11:55:03-07:00"}
# {"action":"set_shard_read_only","level":"warning","msg":"Set READONLY, disk usage currently at 97.30%, threshold set to 90.00%","path":"/Users/tdubon/.local/share/weaviate","time":"2023-10-04T11:55:03-07:00"}

# %%
def add_podcasts(batch_size = 1):
    no_items_in_batch = 0
    for item in datastore:
        podcast_object = {
            "title": item["title"],
            "transcript": item["transcript"]
        }

        podcast_uuid = generate_uuid5('podcast', item["title"] + item["transcript"])
        client.batch.add_data_object(podcast_object, "Podcast", podcast_uuid)
        no_items_in_batch += 1

        if no_items_in_batch >= batch_size:
            results = client.batch.create_objects()

            for result in results:
                    if result['result'] != {}:
                        helper.log(result['result'])

            message = str(item["title"]) + ' imported'
            helper.log(message)

            no_items_in_batch = 0

    client.batch.create_objects()

# %%
add_podcasts(1)
# Out:
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.134682 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.134962 | go-time-154.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.152580 | go-time-155.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.172640 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.172665 | go-time-156.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.189123 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.189153 | go-time-157.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.223693 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.223718 | go-time-158.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.233839 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.233864 | go-time-159.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.239869 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.239893 | go-time-16.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.250318 | go-time-160.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.257169 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.257198 | go-time-161.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.263879 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.263905 | go-time-162.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.271859 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.271883 | go-time-163.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.278988 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.279013 | go-time-164.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.286600 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.286624 | go-time-165.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.292048 | go-time-166.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.298345 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.298372 | go-time-167.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.306553 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.306581 | go-time-168.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.314620 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.314646 | go-time-169.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.320418 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.320442 | go-time-17.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.326673 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.326703 | go-time-170.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.331975 | go-time-171.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.411040 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.411069 | go-time-172.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.420803 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.420828 | go-time-173.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.428193 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.428218 | go-time-174.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.436611 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51.436641 | go-time-175.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:51.450060 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:51
md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.002686 | practical-ai-136.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.007738 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.007760 | practical-ai-137.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.013539 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.013589 | practical-ai-138.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.023746 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.023874 | practical-ai-139.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.029315 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.029357 | practical-ai-14.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.036862 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.036886 | practical-ai-140.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.042389 | practical-ai-141.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# ...
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.841275 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.841298 | the-changelog-332.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.849172 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.849199 | the-changelog-333.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.858111 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.858134 | the-changelog-334.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.868505 | the-changelog-335.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.875107 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.875152 | the-changelog-336.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.881937 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.881964 | the-changelog-337.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.887244 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.887267 | the-changelog-338.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.891841 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.891865 | the-changelog-339.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.897122 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.897148 | the-changelog-340.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.901952 | the-changelog-341.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.907261 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.907285 | the-changelog-342.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.912986 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.913015 | the-changelog-343.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.919054 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.919077 | the-changelog-344.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.923690 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.923713 | the-changelog-345.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.928684 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.928723 | the-changelog-346.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.933908 | the-changelog-347.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.938654 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.938678 | the-changelog-348.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.943858 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.943883 | the-changelog-349.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.951349 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.951399 | the-changelog-350.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.957233 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.957257 | the-changelog-351.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.962545 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.962567 | the-changelog-352.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.969587 | the-changelog-353.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.973773 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.973796 | the-changelog-354.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.979226 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.979249 | the-changelog-355.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.984881 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.984906 | the-changelog-356.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.990393 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.990417 | the-changelog-357.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:52.996412 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:52.996437 | the-changelog-358.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:53.001987 | the-changelog-359.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:53.006588 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:53.006612 | the-changelog-360.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:53.011966 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:53.011990 | the-changelog-361.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:53.016901 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:53.016925 | the-changelog-362.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:53.022819 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:53.022843 | the-changelog-363.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:53.027373 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:53.027459 | the-changelog-364.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:53.033325 | the-changelog-365.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:53.038063 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:53.038087 | the-changelog-366.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:53.043276 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:53.043299 | the-changelog-367.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:53.049401 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:53.049425 | the-changelog-368.md imported
# {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}
# 2023-10-04 19:34:53.058298 | {'errors': {'error': [{'message': 'update vector: Cohere API Key: no api key found neither in request header: X-Cohere-Api-Key nor in environment variable under COHERE_APIKEY'}]}, 'status': 'FAILED'}
# 2023-10-04 19:34:53.058324 | the-changelog-369.md imported

# %% [markdown]
# Next you would implement the pipeline for whatever steps you need to take to query your data, such as semantic search, generative search, question/answering.

# %%
#Question answering - search 

response = (
    client.query
    .get("Podcast", ["transcript"])
    .with_near_text({"concepts": ["biology"]})
    .with_limit(3)
    .do()
)

print(json.dumps(res, indent=2))
# Out:
# {
#   "errors": [
#     {
#       "locations": [
#         {
#           "column": 23,
#           "line": 1
#         }
#       ],
#       "message": "Unknown argument \"ask\" on field \"Podcast\" of type \"GetObjectsObj\".",
#       "path": null
#     },
#     {
#       "locations": [
#         {
#           "column": 99,
#           "line": 1
#         }
#       ],
#       "message": "Cannot query field \"question\" on type \"Podcast\".",
#       "path": null
#     },
#     {
#       "locations": [
#         {
#           "column": 121,
#           "line": 1
#         }
#       ],
#       "message": "Cannot query field \"answer\" on type \"PodcastAdditional\".",
#       "path": null
#     }
#   ]
# }
